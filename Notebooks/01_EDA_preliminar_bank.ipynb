# %% [markdown]
# Análisis preliminar conjunto de datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl
from datetime import datetime, timedelta

# %%
pd.set_option("display.max_columns", None)

# %%
df_bank_0 = pd.read_csv(r"C:\Users\Renée García Mathieu\Desktop\Proyecto_EDA_con_Python_CGG\Raw Data\bank-additional.csv", index_col= 0)
df_bank_0.sample(3)
# Out:
#         age         job  marital            education  default  housing  loan  \
# 17924  36.0  technician  MARRIED          high.school      0.0      1.0   0.0
# 21640  54.0  technician  MARRIED  professional.course      0.0      0.0   0.0
# 25289  34.0    services   SINGLE          high.school      0.0      0.0   0.0
#
#         contact  duration  campaign  pdays  previous     poutcome  \
# 17924  cellular       123         4    999         0  NONEXISTENT
# 21640  cellular        99         1    999         0  NONEXISTENT
# 25289  cellular       202         2    999         0  NONEXISTENT
#
#        emp.var.rate cons.price.idx cons.conf.idx euribor3m nr.employed   y  \
# 17924           1.4         93,918         -42,7     4,961      5228,1  no
# 21640           1.4         93,444         -36,1     4,963      5228,1  no
# 25289          -0.1           93,2           -42     4,153      5195,8  no
#
#                 date  latitude  longitude  \
# ...

# %%
excel_data = pd.read_excel(r"C:\Users\Renée García Mathieu\Desktop\Proyecto_EDA_con_Python_CGG\Raw Data\customer-details.xlsx", sheet_name=None, index_col=0)
df_customer_0 = pd.concat(excel_data.values(), ignore_index=True)
df_customer_0
# Out:
#        Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0      161770        1         0  2012-04-04                 29
# 1       85477        1         1  2012-12-30                  7
# 2      147233        1         1  2012-02-02                  5
# 3      121393        1         2  2012-12-21                 29
# 4       63164        1         2  2012-06-20                 20
# ...       ...      ...       ...         ...                ...
# 43165  156980        1         2  2014-05-17                  7
# 43166  139820        0         0  2014-09-29                  1
# 43167   78470        2         2  2014-10-28                 12
# 43168  144218        0         1  2014-07-01                  9
# 43169  115155        0         2  2014-12-25                  7
#
#                                          ID
# 0      089b39d8-e4d0-461b-87d4-814d71e0e079
# 1      e9d37224-cb6f-4942-98d7-46672963d097
# 2      3f9f49b5-e410-4948-bf6e-f9244f04918b
# ...

# %%
df_bank = df_bank_0.copy()

df_customer = df_customer_0.copy()

# %%
df_bank.head()
# Out:
#     age        job  marital    education  default  housing  loan    contact  \
# 0   NaN  housemaid  MARRIED     basic.4y      0.0      0.0   0.0  telephone
# 1  57.0   services  MARRIED  high.school      NaN      0.0   0.0  telephone
# 2  37.0   services  MARRIED  high.school      0.0      1.0   0.0  telephone
# 3  40.0     admin.  MARRIED     basic.6y      0.0      0.0   0.0  telephone
# 4  56.0   services  MARRIED  high.school      0.0      0.0   1.0  telephone
#
#    duration  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0       261         1    999         0  NONEXISTENT           1.1
# 1       149         1    999         0  NONEXISTENT           1.1
# 2       226         1    999         0  NONEXISTENT           1.1
# 3       151         1    999         0  NONEXISTENT           1.1
# 4       307         1    999         0  NONEXISTENT           1.1
#
#   cons.price.idx cons.conf.idx euribor3m nr.employed   y                date  \
# ...

# %%
df_customer.head()
# Out:
#    Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0  161770        1         0  2012-04-04                 29
# 1   85477        1         1  2012-12-30                  7
# 2  147233        1         1  2012-02-02                  5
# 3  121393        1         2  2012-12-21                 29
# 4   63164        1         2  2012-06-20                 20
#
#                                      ID
# 0  089b39d8-e4d0-461b-87d4-814d71e0e079
# 1  e9d37224-cb6f-4942-98d7-46672963d097
# 2  3f9f49b5-e410-4948-bf6e-f9244f04918b
# 3  9991fafb-4447-451a-8be2-b0df6098d13e
# 4  eca60b76-70b6-4077-80ba-bc52e8ebb0eb

# %%
df_bank.shape
print(f"Tenemos un total de {df_bank.shape[0]} filas y de {df_bank.shape[1]} columnas")
# Out:
# Tenemos un total de 43000 filas y de 23 columnas

# %%
df_customer.shape
print(f"Tenemos un total de {df_customer.shape[0]} filas y de {df_customer.shape[1]} columnas")
# Out:
# Tenemos un total de 43170 filas y de 6 columnas

# %%
df_bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43000 entries, 0 to 27570
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             37880 non-null  float64
#  1   job             42655 non-null  object
#  2   marital         42915 non-null  object
#  3   education       41193 non-null  object
#  4   default         34019 non-null  float64
#  5   housing         41974 non-null  float64
#  6   loan            41974 non-null  float64
#  7   contact         43000 non-null  object
#  8   duration        43000 non-null  int64
#  9   campaign        43000 non-null  int64
#  10  pdays           43000 non-null  int64
#  11  previous        43000 non-null  int64
#  12  poutcome        43000 non-null  object
#  13  emp.var.rate    43000 non-null  float64
#  14  cons.price.idx  42529 non-null  object
#  15  cons.conf.idx   43000 non-null  object
#  16  euribor3m       33744 non-null  object
# ...

# %%
df_customer.info(9)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43170 entries, 0 to 43169
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Income             43170 non-null  int64
#  1   Kidhome            43170 non-null  int64
#  2   Teenhome           43170 non-null  int64
#  3   Dt_Customer        43170 non-null  datetime64[ns]
#  4   NumWebVisitsMonth  43170 non-null  int64
#  5   ID                 43170 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 2.0+ MB

# %%
df_bank.isnull().sum()
# Out:
# age               5120
# job                345
# marital             85
# education         1807
# default           8981
# housing           1026
# loan              1026
# contact              0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx     471
# cons.conf.idx        0
# euribor3m         9256
# nr.employed          0
# y                    0
# date               248
# latitude             0
# longitude            0
# id_                  0
# dtype: int64

# %%
df_customer.isnull().sum()
# Out:
# Income               0
# Kidhome              0
# Teenhome             0
# Dt_Customer          0
# NumWebVisitsMonth    0
# ID                   0
# dtype: int64

# %%
porcentaje_nulos = (df_bank.isnull().sum()/ len(df)) * 100
porcentaje_nulos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 porcentaje_nulos = (df_bank.isnull().sum()/ len(df)) * 100
#       2 porcentaje_nulos
#
# NameError: name 'df' is not defined

# %%
df_bank.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_customer.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_bank.describe().T
# Out:
#                 count        mean         std      min        25%       50%  \
# age           37880.0   39.977112   10.437957   17.000   32.00000   38.0000
# default       34019.0    0.000088    0.009390    0.000    0.00000    0.0000
# housing       41974.0    0.535998    0.498708    0.000    0.00000    1.0000
# loan          41974.0    0.155620    0.362499    0.000    0.00000    0.0000
# duration      43000.0  257.739279  258.666033    0.000  102.00000  179.0000
# campaign      43000.0    2.567233    2.772294    1.000    1.00000    2.0000
# pdays         43000.0  962.330953  187.260394    0.000  999.00000  999.0000
# previous      43000.0    0.174023    0.497366    0.000    0.00000    0.0000
# emp.var.rate  43000.0    0.077128    1.573898   -3.400   -1.80000    1.1000
# latitude      43000.0   36.856697    7.225948   24.396   30.61475   36.7610
# longitude     43000.0  -95.939067   16.752282 -124.997 -110.49425  -95.8995
#
#                     75%       max
# ...

# %%
df_customer.describe().T
# Out:
#                      count                           mean  \
# Income             43170.0                   93227.389622
# Kidhome            43170.0                       1.004749
# Teenhome           43170.0                       0.998633
# Dt_Customer          43170  2013-05-11 22:09:47.407922176
# NumWebVisitsMonth  43170.0                       16.59129
#
#                                    min                  25%  \
# Income                          5841.0              49608.0
# Kidhome                            0.0                  0.0
# Teenhome                           0.0                  0.0
# Dt_Customer        2012-01-01 00:00:00  2012-07-16 00:00:00
# NumWebVisitsMonth                  1.0                  9.0
#
#                                    50%                  75%  \
# Income                         93009.5             136740.5
# Kidhome                            1.0                  2.0
# Teenhome                           1.0                  2.0
# ...

# %%
df_bank.nunique()
# Out:
# age                  78
# job                  11
# marital               3
# education             7
# default               2
# housing               2
# loan                  2
# contact               2
# duration           1540
# campaign             42
# pdays                27
# previous              8
# poutcome              3
# emp.var.rate         10
# cons.price.idx       26
# cons.conf.idx        26
# euribor3m           309
# nr.employed          11
# y                     2
# date               1825
# latitude          20491
# longitude         30448
# id_               43000
# dtype: int64

# %%
df_customer.nunique()
# Out:
# Income               38310
# Kidhome                  3
# Teenhome                 3
# Dt_Customer           1096
# NumWebVisitsMonth       32
# ID                   43170
# dtype: int64

# %%
for col in df_bank.select_dtypes(include="object").columns:
    print(col.upper())
    print(df_bank[col].value_counts())
    print("--------------")
# Out:
# JOB
# job
# admin.           10873
# blue-collar       9654
# technician        7026
# services          4162
# management        3050
# retired           1790
# entrepreneur      1522
# self-employed     1489
# housemaid         1123
# unemployed        1063
# student            903
# Name: count, dtype: int64
# --------------
# MARITAL
# marital
# MARRIED     25999
# SINGLE      12105
# DIVORCED     4811
# Name: count, dtype: int64
# --------------
# EDUCATION
# education
# university.degree      12722
# high.school             9925
# basic.9y                6309
# professional.course     5477
# basic.4y                4356
# basic.6y                2386
# illiterate                18
# Name: count, dtype: int64
# --------------
# CONTACT
# contact
# cellular     27396
# telephone    15604
# Name: count, dtype: int64
# --------------
# POUTCOME
# poutcome
# NONEXISTENT    37103
# FAILURE         4461
# SUCCESS         1436
# Name: count, dtype: int64
# --------------
# ...

# %%
for col in df_customer.select_dtypes(include="object").columns:
    print(col.upper())
    print(df_customer[col].value_counts())
    print("--------------")
# Out:
# ID
# ID
# 9727bc06-c11a-461a-a5bb-3d210467cc2a    1
# 089b39d8-e4d0-461b-87d4-814d71e0e079    1
# 5006b75e-18bb-46e9-ae1a-89f7eb79cc8a    1
# e554d2ad-6c83-4603-93d4-fc596b807eff    1
# 3959015a-9713-4877-9a43-740e34c29eaf    1
#                                        ..
# 5e3483e5-236d-437d-8351-541f9d09b9dd    1
# d63ede72-0b6d-45b1-8872-385ac6897f65    1
# eca60b76-70b6-4077-80ba-bc52e8ebb0eb    1
# 9991fafb-4447-451a-8be2-b0df6098d13e    1
# 3f9f49b5-e410-4948-bf6e-f9244f04918b    1
# Name: count, Length: 43170, dtype: int64
# --------------

# %%
df_bank.rename(columns={"id_":"ID"}, inplace=True)
df_bank.sample(3)
# Out:
#         age            job  marital          education  default  housing  \
# 3799   28.0       services   SINGLE           basic.9y      0.0      1.0
# 11844  33.0  self-employed   SINGLE  university.degree      0.0      NaN
# 7458   30.0    blue-collar  MARRIED           basic.4y      NaN      1.0
#
#        loan    contact  duration  campaign  pdays  previous     poutcome  \
# 3799    0.0  telephone       148         2    999         0  NONEXISTENT
# 11844   NaN  telephone        38         5    999         0  NONEXISTENT
# 7458    0.0  telephone       176         4    999         0  NONEXISTENT
#
#        emp.var.rate cons.price.idx cons.conf.idx euribor3m nr.employed   y  \
# 3799            1.1         93,994         -36,4     4,859        5191  no
# 11844           1.4         94,465         -41,8     4,959      5228,1  no
# 7458            1.1         93,994         -36,4       NaN        5191  no
#
#                   date  latitude  longitude  \
# ...

# %%
df_merge = pd.merge(df_customer, df_bank, on="ID", how="left")
df_merge.sample(3)
# Out:
#        Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 30866  138478        2         0  2014-08-19                 11
# 27556   53047        0         1  2013-12-22                 23
# 5458    75054        1         2  2012-01-13                 18
#
#                                          ID   age          job  marital  \
# 30866  6641849d-bc2c-41cb-9a9b-e2a5f28b544d  50.0  blue-collar  MARRIED
# 27556  87ceae84-77a2-46bc-b482-72b038b416fc  47.0   management  MARRIED
# 5458   f0f1da64-fb41-4f2e-8c1d-d3b12907f97d  40.0  blue-collar  MARRIED
#
#          education  default  housing  loan    contact  duration  campaign  \
# 30866     basic.4y      0.0      0.0   0.0   cellular     166.0       2.0
# 27556  high.school      0.0      1.0   1.0   cellular     225.0       3.0
# 5458      basic.4y      0.0      0.0   0.0  telephone     283.0      11.0
#
#        pdays  previous     poutcome  emp.var.rate cons.price.idx  \
# ...

# %%
df_merge.to_csv(r"C:\Users\Renée García Mathieu\Desktop\Proyecto_EDA_con_Python_CGG\Transformed_Data\Datos_Fusionados_Bank", index=False)
